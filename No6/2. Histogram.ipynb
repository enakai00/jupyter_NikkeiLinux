# %% [markdown]
# **[2-1]** NumPy, matplotlibに加えて、pandasをインポートします。

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **[2-2]** タイタニック号のデータを読み込んで、データフレーム data に格納します。

# %%
data = pd.read_csv('http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.csv')

# %% [markdown]
# **[2-3]** 年齢（age）だけを含むデータフレームを作成して欠損値を削除した後、ヒストグラムを描きます。

# %%
df = data[['age']].dropna()
df.plot(kind='hist', bins=20)

# %% [markdown]
# **[2-3]** 乗船チケットの価格（fare）だけを含むデータフレームを作成して欠損値を削除した後、ヒストグラムを描きます。

# %%
df = data[['fare']].dropna()
df.plot(kind='hist', bins=20)

# %% [markdown]
# **[2-4]** 乗船チケットの価格（fare）について、平均値と中央値を計算します。

# %%
df.mean()
# Out:
# fare    33.295479
# dtype: float64

# %%
df.median()
# Out:
# fare    14.4542
# dtype: float64
